# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the .dta file
file_path = "C:/Users/kitti/VSCodeProjects/TVSepProject/TVSep-sample-data/Full_All_TVSEP.dta"  # Replace with the path to your .dta file
data = pd.read_stata(file_path)

# Display the first few rows
print("First 5 rows of data:")
print(data.head())

# Display basic information about the dataset
print("\nDataset Info:")
print(data.info())

# Display summary statistics
print("\nDescriptive Statistics:")
print(data.describe())

# Check for missing values
print("\nMissing Values Per Column:")
print(data.isnull().sum())
# Out:
# First 5 rows of data:
#           QID   country        prov                distr      subdistr  \
# 0  3101030202  Thailand  31-Buriram  3101-Mueang Buriram  310103-Samet
# 1  3101030204  Thailand  31-Buriram  3101-Mueang Buriram  310103-Samet
# 2  3101030205  Thailand  31-Buriram  3101-Mueang Buriram  310103-Samet
# 3  3101030207  Thailand  31-Buriram  3101-Mueang Buriram  310103-Samet
# 4  3101030208  Thailand  31-Buriram  3101-Mueang Buriram  310103-Samet
#
#                  vill   hhid    year head_gender  head_age  ... managed_land  \
# 0  31010302-Khok Phet  695.0  2007.0      female      66.0  ...         0.00
# 1  31010302-Khok Phet  832.0  2007.0      female      65.0  ...         5.12
# 2  31010302-Khok Phet  825.0  2007.0      female      43.0  ...         1.12
# 3  31010302-Khok Phet   29.0  2007.0        male      37.0  ...         0.00
# 4  31010302-Khok Phet  820.0  2007.0        male      42.0  ...         0.00
#
# ...

# %%
# Replace 'column_name' with the name of the column you want to visualize
column_names = list(data.columns)
print(column_names)
# Out:
# ['QID', 'country', 'prov', 'distr', 'subdistr', 'vill', 'hhid', 'year', 'head_gender', 'head_age', 'head_marital_status', 'head_ethnicity', 'head_highest_edu', 'hh_size', 'no_children_under6', 'no_children_schoolage', 'no_adult', 'no_elderly', 'PYIncCap', 'PMIncCap', 'PDIncCap', 'PYConsaggCap', 'PMConsaggCap', 'PDConsaggCap', 'total_area', 'owned_land', 'managed_land', 'no_land_plot', 'mean_distance', 'no_shocks', 'loss_shocks', 'no_mobilphone', 'total_asset', 'no_smartphone', 'cov_infected_cov', 'cov_vaccinated_mem']

# %%
data['head_ethnicity'].hist(bins=20)
plt.title("Histogram of head_ethnicity")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
data.to_csv("C:/Users/kitti/VSCodeProjects/TVSepProject/TVSep-sample-data/CSV/Full_All_TVSEP.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data.to_csv("C:/Users/kitti/VSCodeProjects/TVSepProject/TVSep-sample-data/CSV/Full_All_TVSEP.csv")
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
